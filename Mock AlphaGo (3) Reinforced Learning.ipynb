# %% [markdown]
# # Mock AlphaGo (3) - Reinforced Learning
# In this notebook, we will train the policy network by letting them compete each other according to DeepMind:
#
# > We further trained the policy network by policy gradient reinforcement learning.
# Each iteration consisted of a mini-batch of n games played in parallel, between
# the current policy network $p_\rho$ that is being trained, and an opponent $p_\rho-$
# that uses parameters $\rho^-$ from a previous iteration, randomly sampled from
# a pool $O$ of opponents, so as to increase the stability of training. Weights were
# initialized to $\rho = \rho^- = \sigma$. Every 500 iterations, we added the current
# parameters $\rho$ to the opponent pool. Each game $i$ in the mini-batch was played
# out until termination at step $T^i$, and then scored to determine the outcome
# $z^i_t = \pm r(s_{T^i})$ from each player’s perspective. The games were then replayed
# to determine the policy gradient update, $\Delta\rho = \frac{a}{n}\Sigma^n_{i=1}
# \Sigma^{T^i}_{t=1}\frac{\partial\log p_\rho(a^i_t|s^i_t)}{\partial_\rho}(z^i_t-v(s^i_t))$, using the REINFORCE
# algorithm with baseline $v(s^i_t)$ for variance reduction. On the first pass
# through the training pipeline, the baseline was set to zero; on the second pass
# we used the value network $v_\theta(s)$ as a baseline; this provided a small
# performance boost. The policy network was trained in this way for 10,000
# mini-batches of 128 games, using 50 GPUs, for one day.

# %%
import os, numpy as np
from caffe2.python import core, model_helper, workspace, brew, utils
from caffe2.proto import caffe2_pb2
from sgfutil import BOARD_POSITION

# %matplotlib inline
from matplotlib import pyplot

# how many games will be run in one minibatch
GAMES_BATCHES = 128 # [1,infinity) depends on your hardware
# how many iterations for this tournament
TOURNAMENT_ITERS = 250000 # [1,infinity)

if workspace.has_gpu_support:
    device_opts = core.DeviceOption(caffe2_pb2.CUDA, workspace.GetDefaultGPUID())
    print('Running in GPU mode on default device {}'.format(workspace.GetDefaultGPUID()))
else :
    device_opts = core.DeviceOption(caffe2_pb2.CPU, 0)
    print('Running in CPU mode')

arg_scope = {"order": "NCHW"}

ROOT_FOLDER = os.path.join(os.path.expanduser('~'), 'python', 'tutorial_data','go','param') # folder stores the loss/accuracy log
# Out:
# WARNING:root:This caffe2 python run does not have GPU support. Will run in CPU only mode.
# WARNING:root:Debug message: No module named caffe2_pybind11_state_gpu
# Running in CPU mode

# %% [markdown]
# We need to differentiate primary player and sparring partner. Primary player will learn from the game result

# %%
# who is primary and who is sparring partner? 
PRIMARY_PLAYER = "black" # or white
SPARRING_PLAYER = "white"

### Config for primary player
PRIMARY_WORKSPACE = os.path.join(ROOT_FOLDER, PRIMARY_PLAYER)
PRIMARY_CONV_LEVEL = 4
PRIMARY_FILTERS = 128
PRIMARY_PRE_TRAINED_ITERS = 1
# before traning, where to load the params
PRIMARY_LOAD_FOLDER = os.path.join(ROOT_FOLDER, "RL-conv={}-k={}-iter={}".format(PRIMARY_CONV_LEVEL,PRIMARY_FILTERS,PRIMARY_PRE_TRAINED_ITERS))

### Config for sparring partner
SPARR_WORKSPACE = os.path.join(ROOT_FOLDER, SPARRING_PLAYER)
SPARR_CONV_LEVEL = 13
SPARR_FILTERS = 192
SPARR_PRE_TRAINED_ITERS = 1
# before traning, where to load the params
SPARR_LOAD_FOLDER = os.path.join(ROOT_FOLDER, "RL-conv={}-k={}-iter={}".format(SPARR_CONV_LEVEL,SPARR_FILTERS,SPARR_PRE_TRAINED_ITERS))

print('{}-{}-{}({}) vs. {}-{}-{}({})'.format(
    PRIMARY_CONV_LEVEL, PRIMARY_FILTERS, PRIMARY_PRE_TRAINED_ITERS, PRIMARY_PLAYER,
    SPARR_CONV_LEVEL, SPARR_FILTERS, SPARR_PRE_TRAINED_ITERS, SPARRING_PLAYER))
# Out:
# 4-128-1(black) vs. 13-192-1(white)

# %% [markdown]
# Following training parameters are only for primary player.

# %%
BASE_LR = -0.003 # (-0.003,0) The base Learning Rate

TRAIN_BATCHES = 64 # how many samples will be trained within one mini-batch, depends on your hardware

# after training, where to store the params
SAVE_FOLDER = os.path.join(ROOT_FOLDER, "RL-conv={}-k={}-iter={}".
                           format(PRIMARY_CONV_LEVEL,PRIMARY_FILTERS,PRIMARY_PRE_TRAINED_ITERS+TOURNAMENT_ITERS))
print('After training, result will be saved to {}'.format(SAVE_FOLDER))
# Out:
# After training, result will be saved to /home/wangd/python/tutorial_data/go/param/RL-conv=4-k=128-iter=501

# %% [markdown]
# ## AlphaGo Neural Network Architecture

# %%
from modeling import AddConvModel, AddTrainingOperators

# %% [markdown]
# ## Build the actual network

# %%
import caffe2.python.predictor.predictor_exporter as pe

data = np.empty(shape=(TRAIN_BATCHES,48,19,19), dtype=np.float32)
label = np.empty(shape=(TRAIN_BATCHES,), dtype=np.int32)

# %% [markdown]
# ### Primary player
# >Train Net: Blob('data','label') ==> Predict Net ==> Loss ==> Backward Propergation

# %%
workspace.SwitchWorkspace(PRIMARY_WORKSPACE, True)
# for learning from winner
with core.DeviceScope(device_opts):
    primary_train_model = model_helper.ModelHelper(name="primary_train_model", arg_scope=arg_scope, init_params=True)
    workspace.FeedBlob("data", data, device_option=device_opts)
    predict = AddConvModel(primary_train_model, "data", conv_level=PRIMARY_CONV_LEVEL, filters=PRIMARY_FILTERS)
    workspace.FeedBlob("label", data, device_option=device_opts)
    AddTrainingOperators(primary_train_model, predict, "label", base_lr=BASE_LR)
    workspace.RunNetOnce(primary_train_model.param_init_net)
    workspace.CreateNet(primary_train_model.net, overwrite=True)
# for learning from negative examples
with core.DeviceScope(device_opts):
    primary_train_neg_model = model_helper.ModelHelper(name="primary_train_neg_model", arg_scope=arg_scope, init_params=True)
    #workspace.FeedBlob("data", data, device_option=device_opts)
    predict = AddConvModel(primary_train_neg_model, "data", conv_level=PRIMARY_CONV_LEVEL, filters=PRIMARY_FILTERS)
    #workspace.FeedBlob("label", data, device_option=device_opts)
    AddTrainingOperators(primary_train_neg_model, predict, "label", base_lr=BASE_LR, learn_neg=True)
    workspace.RunNetOnce(primary_train_neg_model.param_init_net)
    workspace.CreateNet(primary_train_neg_model.net, overwrite=True)
    
primary_predict_net = pe.prepare_prediction_net(os.path.join(PRIMARY_LOAD_FOLDER, "policy_model.minidb"),
                                               "minidb", device_option=device_opts)
# Out:
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.
# WARNING:root:You are creating an op that the ModelHelper does not recognize: PadImage.

# %% [markdown]
# ### Sparring partner
# >Predict Net: Blob('data') ==> Predict Net ==> Blob('predict')

# %%
# Initialize sparring partner
workspace.SwitchWorkspace(SPARR_WORKSPACE, True)
sparring_predict_net = pe.prepare_prediction_net(os.path.join(SPARR_LOAD_FOLDER, "policy_model.minidb"),
                                                 "minidb", device_option=device_opts)

# %% [markdown]
# ## Run the tournament and training

# %% [markdown]
# ### Compete

# %%
from go import GameState, BLACK, WHITE, EMPTY, PASS
from preprocessing import Preprocess
from game import DEFAULT_FEATURES
from datetime import datetime

np.random.seed(datetime.now().microsecond)

game_state = [ GameState() for i in range(GAMES_BATCHES) ]
game_result = [0] * GAMES_BATCHES # 0 - Not Ended; BLACK - Black Wins; WHITE - White Wins
p = [ Preprocess(DEFAULT_FEATURES) ] * GAMES_BATCHES
history = [ [] for i in range(GAMES_BATCHES) ]
board = None

# for each step in all games
for step in range(0,500):
    
    board = np.concatenate([p[i].state_to_tensor(game_state[i]).astype(np.float32) for i in range(GAMES_BATCHES)])
    
    if step % 2 == 0:
        current_player = BLACK
        current_color = 'B'
    else:
        current_player = WHITE
        current_color = 'W'

    if step % 2 == (PRIMARY_PLAYER == 'white'):
        # primary player move
        workspace.SwitchWorkspace(PRIMARY_WORKSPACE)
        workspace.FeedBlob('data', board, device_option=device_opts)
        workspace.RunNet(primary_predict_net)
    else:
        # sparring partner move
        workspace.SwitchWorkspace(SPARR_WORKSPACE)
        workspace.FeedBlob('data', board, device_option=device_opts)
        workspace.RunNet(sparring_predict_net)

    predict = workspace.FetchBlob('predict') # [0.01, 0.02, ...] in shape (N,361)
    
    for i in range(GAMES_BATCHES):
        if game_result[i]: # game end
            continue
        else: # game not end
            legal_moves = [ x*19+y for (x,y) in game_state[i].get_legal_moves(include_eyes=False)] # [59, 72, ...] in 1D
            if len(legal_moves) > 0: # at least 1 legal move
                probabilities = predict[i][legal_moves] # [0.02, 0.01, ...]
                # use numpy.random.choice to randomize the step,
                # otherwise use np.argmax to get best choice
                # current_choice = legal_moves[np.argmax(probabilities)]
                current_choice = np.random.choice(legal_moves, 1, p=probabilities/np.sum(probabilities))[0]
                (x, y) = (current_choice/19, current_choice%19)
                history[i].append((current_color, x, y, board[i]))
                game_state[i].do_move(action = (x, y), color = current_player) # End of Game?
                print('game({}) step({}) {} move({},{})'.format(i, step, current_color, x, y))
            else:
                game_state[i].do_move(action = PASS, color = current_player)
                print('game({}) step({}) {} PASS'.format(i, step, current_color))
                game_result[i] = game_state[i].is_end_of_game

    if np.all(game_result):
        break
# Out:
# game(0) step(0) B move(3,3)
# game(1) step(0) B move(16,15)
# game(2) step(0) B move(16,13)
# game(0) step(1) W move(15,3)
# game(1) step(1) W move(3,15)
# game(2) step(1) W move(13,16)
# game(0) step(2) B move(4,15)
# game(1) step(2) B move(15,3)
# game(2) step(2) B move(13,15)
# game(0) step(3) W move(16,15)
# game(1) step(3) W move(3,2)
# game(2) step(3) W move(12,15)
# game(0) step(4) B move(3,12)
# game(1) step(4) B move(5,16)
# game(2) step(4) B move(14,15)
# game(0) step(5) W move(14,16)
# game(1) step(5) W move(2,13)
# game(2) step(5) W move(14,16)
# game(0) step(6) B move(16,5)
# game(1) step(6) B move(14,16)
# game(2) step(6) B move(15,16)
# game(0) step(7) W move(13,2)
# game(1) step(7) W move(2,4)
# game(2) step(7) W move(15,17)
# game(0) step(8) B move(16,2)
# game(1) step(8) B move(9,15)
# game(2) step(8) B move(12,16)
# game(0) step(9) W move(16,3)
# game(1) step(9) W move(16,5)
# game(2) step(9) W move(16,16)
# game(0) step(10) B move(17,3)
# game(1) step(10) B move(3,12)
# game(2) step(10) B move(15,15)
# game(0) step(11) W move(17,4)
# game(1) step(11) W move(2,12)
# game(2) step(11) W move(16,15)
# game(0) step(12) B move(15,2)
# game(1) step(12) B move(3,11)
# game(2) step(12) B move(16,17)
# game(0) step(13) W move(17,2)
# game(1) step(13) W move(5,15)
# game(2) step(13) W move(14,17)
# game(0) step(14) B move(17,1)
# game(1) step(14) B move(6,15)
# game(2) step(14) B move(12,17)
# game(0) step(15) W move(18,3)
# game(1) step(15) W move(5,14)
# game(2) step(15) W move(17,17)
# game(0) step(16) B move(14,2)
# game(1) step(16) B move(6,14)
# game(2) step(16) B move(11,15)
# game(0) step(17) W move(14,3)
# game(1) step(17) W move(4,16)
# game(2) step(17) W move(15,3)
# game(0) step(18) B move(13,1)
# game(1) step(18) B move(5,17)
# game(2) step(18) B move(3,16)
# game(0) step(19) W move(12,2)
# game(1) step(19) W move(5,13)
# game(2) step(19) W move(3,3)
# game(0) step(20) B move(14,1)
# game(1) step(20) B move(6,13)
# game(2) step(20) B move(13,17)
# game(0) step(21) W move(12,1)
# game(1) step(21) W move(5,12)
# game(2) step(21) W move(15,14)
# game(0) step(22) B move(3,6)
# game(1) step(22) B move(1,10)
# game(2) step(22) B move(16,14)
# game(0) step(23) W move(2,16)
# game(1) step(23) W move(4,17)
# game(2) step(23) W move(16,18)
# game(0) step(24) B move(2,15)
# game(1) step(24) B move(6,11)
# game(2) step(24) B move(14,18)
# game(0) step(25) W move(18,1)
# game(1) step(25) W move(5,11)
# game(2) step(25) W move(12,14)
# game(0) step(26) B move(16,8)
# game(1) step(26) B move(6,10)
# game(2) step(26) B move(13,14)
# game(0) step(27) W move(16,10)
# game(1) step(27) W move(5,10)
# game(2) step(27) W move(13,13)
# game(0) step(28) B move(11,16)
# game(1) step(28) B move(6,9)
# game(2) step(28) B move(11,14)
# game(0) step(29) W move(14,8)
# game(1) step(29) W move(5,9)
# game(2) step(29) W move(16,11)
# game(0) step(30) B move(14,9)
# game(1) step(30) B move(6,8)
# game(2) step(30) B move(12,13)
# game(0) step(31) W move(15,9)
# game(1) step(31) W move(5,8)
# game(2) step(31) W move(3,9)
# game(0) step(32) B move(15,8)
# game(1) step(32) B move(5,7)
# game(2) step(32) B move(16,9)
# game(0) step(33) W move(13,8)
# game(1) step(33) W move(4,7)
# game(2) step(33) W move(14,10)
# game(0) step(34) B move(14,10)
# game(1) step(34) B move(6,6)
# game(2) step(34) B move(16,5)
# game(0) step(35) W move(16,9)
# game(1) step(35) W move(4,6)
# game(2) step(35) W move(13,2)
# game(0) step(36) B move(17,8)
# game(1) step(36) B move(15,11)
# game(2) step(36) B move(14,9)
# game(0) step(37) W move(16,12)
# game(1) step(37) W move(16,9)
# game(2) step(37) W move(13,10)
# game(0) step(38) B move(12,8)
# game(1) step(38) B move(16,7)
# game(2) step(38) B move(13,9)
# game(0) step(39) W move(13,9)
# game(1) step(39) W move(14,9)
# game(2) step(39) W move(11,10)
# game(0) step(40) B move(17,10)
# game(1) step(40) B move(13,11)
# game(2) step(40) B move(12,11)
# game(0) step(41) W move(17,9)
# game(1) step(41) W move(15,6)
# game(2) step(41) W move(12,10)
# game(0) step(42) B move(18,9)
# game(1) step(42) B move(16,11)
# game(2) step(42) B move(6,16)
# game(0) step(43) W move(17,11)
# game(1) step(43) W move(11,16)
# game(2) step(43) W move(2,14)
# game(0) step(44) B move(18,10)
# game(1) step(44) B move(12,2)
# game(2) step(44) B move(8,15)
# game(0) step(45) W move(15,11)
# game(1) step(45) W move(11,14)
# game(2) step(45) W move(16,7)
# game(0) step(46) B move(18,8)
# game(1) step(46) B move(11,12)
# game(2) step(46) B move(15,7)
# game(0) step(47) W move(15,6)
# game(1) step(47) W move(14,15)
# game(2) step(47) W move(15,6)
# game(0) step(48) B move(15,5)
# game(1) step(48) B move(15,15)
# game(2) step(48) B move(15,9)
# game(0) step(49) W move(17,5)
# game(1) step(49) W move(13,16)
# game(2) step(49) W move(16,6)
# game(0) step(50) B move(14,6)
# game(1) step(50) B move(14,14)
# game(2) step(50) B move(5,2)
# game(0) step(51) W move(14,7)
# game(1) step(51) W move(13,15)
# game(2) step(51) W move(2,5)
# game(0) step(52) B move(15,7)
# game(1) step(52) B move(14,8)
# game(2) step(52) B move(2,6)
# game(0) step(53) W move(13,11)
# game(1) step(53) W move(15,8)
# game(2) step(53) W move(7,2)
# game(0) step(54) B move(12,5)
# game(1) step(54) B move(14,7)
# game(2) step(54) B move(14,6)
# game(0) step(55) W move(13,4)
# game(1) step(55) W move(15,7)
# game(2) step(55) W move(15,5)
# game(0) step(56) B move(12,7)
# game(1) step(56) B move(16,8)
# game(2) step(56) B move(3,6)
# game(0) step(57) W move(13,6)
# game(1) step(57) W move(15,9)
# game(2) step(57) W move(3,5)
# game(0) step(58) B move(13,5)
# game(1) step(58) B move(14,6)
# game(2) step(58) B move(9,2)
# game(0) step(59) W move(14,5)
# game(1) step(59) W move(17,9)
# game(2) step(59) W move(5,3)
# game(0) step(60) B move(16,6)
# game(1) step(60) B move(15,5)
# game(2) step(60) B move(6,2)
# game(0) step(61) W move(14,6)
# game(1) step(61) W move(16,6)
# game(2) step(61) W move(6,3)
# game(0) step(62) B move(13,10)
# game(1) step(62) B move(17,7)
# game(2) step(62) B move(7,1)
# game(0) step(63) W move(12,10)
# game(1) step(63) W move(12,9)
# game(2) step(63) W move(7,3)
# game(0) step(64) B move(12,9)
# game(1) step(64) B move(16,4)
# game(2) step(64) B move(4,2)
# game(0) step(65) W move(14,11)
# game(1) step(65) W move(13,8)
# game(2) step(65) W move(2,8)
# game(0) step(66) B move(7,15)
# game(1) step(66) B move(13,7)
# game(2) step(66) B move(16,12)
# game(0) step(67) W move(17,6)
# game(1) step(67) W move(12,7)
# game(2) step(67) W move(15,11)
# game(0) step(68) B move(12,14)
# game(1) step(68) B move(12,6)
# game(2) step(68) B move(17,11)
# game(0) step(69) W move(11,10)
# game(1) step(69) W move(14,5)
# game(2) step(69) W move(8,10)
# game(0) step(70) B move(13,17)
# game(1) step(70) B move(13,6)
# game(2) step(70) B move(17,15)
# game(0) step(71) W move(10,9)
# game(1) step(71) W move(11,6)
# game(2) step(71) W move(17,16)
# game(0) step(72) B move(15,15)
# game(1) step(72) B move(11,5)
# game(2) step(72) B move(18,15)
# game(0) step(73) W move(15,14)
# game(1) step(73) W move(10,5)
# game(2) step(73) W move(18,16)
# game(0) step(74) B move(16,16)
# game(1) step(74) B move(13,5)
# game(2) step(74) B move(18,11)
# game(0) step(75) W move(15,16)
# game(1) step(75) W move(11,4)
# game(2) step(75) W move(3,2)
# game(0) step(76) B move(14,15)
# game(1) step(76) B move(14,4)
# game(2) step(76) B move(4,3)
# game(0) step(77) W move(13,15)
# game(1) step(77) W move(11,2)
# game(2) step(77) W move(4,4)
# game(0) step(78) B move(14,14)
# game(1) step(78) B move(12,1)
# game(2) step(78) B move(3,1)
# game(0) step(79) W move(13,14)
# game(1) step(79) W move(7,7)
# game(2) step(79) W move(2,1)
# game(0) step(80) B move(16,14)
# game(1) step(80) B move(7,8)
# game(2) step(80) B move(4,1)
# game(0) step(81) W move(14,13)
# game(1) step(81) W move(6,7)
# game(2) step(81) W move(8,1)
# game(0) step(82) B move(17,15)
# game(1) step(82) B move(9,8)
# game(2) step(82) B move(8,2)
# game(0) step(83) W move(15,15)
# game(1) step(83) W move(12,5)
# game(2) step(83) W move(6,1)
# game(0) step(84) B move(16,17)
# game(1) step(84) B move(8,7)
# game(2) step(84) B move(9,1)
# game(0) step(85) W move(3,15)
# game(1) step(85) W move(13,4)
# game(2) step(85) W move(7,0)
# game(0) step(86) B move(3,14)
# game(1) step(86) B move(14,5)
# game(2) step(86) B move(14,12)
# game(0) step(87) W move(3,16)
# game(1) step(87) W move(14,3)
# game(2) step(87) W move(4,7)
# game(0) step(88) B move(1,16)
# game(1) step(88) B move(15,4)
# game(2) step(88) B move(5,6)
# game(0) step(89) W move(1,17)
# game(1) step(89) W move(14,2)
# game(2) step(89) W move(4,6)
# game(0) step(90) B move(1,15)
# game(1) step(90) B move(12,3)
# game(2) step(90) B move(1,5)
# game(0) step(91) W move(4,16)
# game(1) step(91) W move(12,4)
# game(2) step(91) W move(1,3)
# game(0) step(92) B move(5,15)
# game(1) step(92) B move(17,5)
# game(2) step(92) B move(11,8)
# game(0) step(93) W move(6,17)
# game(1) step(93) W move(17,6)
# game(2) step(93) W move(9,4)
# game(0) step(94) B move(7,17)
# game(1) step(94) B move(18,6)
# game(2) step(94) B move(10,4)
# game(0) step(95) W move(6,16)
# game(1) step(95) W move(17,4)
# game(2) step(95) W move(10,5)
# game(0) step(96) B move(7,16)
# game(1) step(96) B move(17,3)
# game(2) step(96) B move(11,4)
# game(0) step(97) W move(0,17)
# game(1) step(97) W move(18,5)
# game(2) step(97) W move(11,5)
# game(0) step(98) B move(8,11)
# game(1) step(98) B move(16,2)
# game(2) step(98) B move(12,5)
# game(0) step(99) W move(8,9)
# game(1) step(99) W move(11,1)
# game(2) step(99) W move(12,6)
# game(0) step(100) B move(6,2)
# game(1) step(100) B move(14,1)
# game(2) step(100) B move(11,6)
# game(0) step(101) W move(6,15)
# game(1) step(101) W move(5,6)
# game(2) step(101) W move(9,5)
# game(0) step(102) B move(6,14)
# game(1) step(102) B move(9,5)
# game(2) step(102) B move(12,3)
# game(0) step(103) W move(5,16)
# game(1) step(103) W move(15,1)
# game(2) step(103) W move(13,5)
# game(0) step(104) B move(18,12)
# game(1) step(104) B move(18,3)
# game(2) step(104) B move(15,2)
# game(0) step(105) W move(8,5)
# game(1) step(105) W move(15,2)
# game(2) step(105) W move(13,3)
# game(0) step(106) B move(8,2)
# game(1) step(106) B move(16,3)
# game(2) step(106) B move(12,4)
# game(0) step(107) W move(6,9)
# game(1) step(107) W move(10,11)
# game(2) step(107) W move(10,3)
# game(0) step(108) B move(7,14)
# game(1) step(108) B move(10,12)
# game(2) step(108) B move(11,1)
# game(0) step(109) W move(17,7)
# game(1) step(109) W move(9,17)
# game(2) step(109) W move(16,2)
# game(0) step(110) B move(18,7)
# game(1) step(110) B move(10,15)
# game(2) step(110) B move(14,5)
# game(0) step(111) W move(16,7)
# game(1) step(111) W move(11,15)
# game(2) step(111) W move(14,7)
# game(0) step(112) B move(1,6)
# game(1) step(112) B move(10,16)
# game(2) step(112) B move(13,7)
# game(0) step(113) W move(4,9)
# game(1) step(113) W move(10,17)
# game(2) step(113) W move(15,8)
# game(0) step(114) B move(18,6)
# game(1) step(114) B move(10,4)
# game(2) step(114) B move(14,8)
# game(0) step(115) W move(9,12)
# game(1) step(115) W move(11,3)
# game(2) step(115) W move(13,4)
# game(0) step(116) B move(15,17)
# game(1) step(116) B move(10,6)
# game(2) step(116) B move(12,2)
# game(0) step(117) W move(18,11)
# game(1) step(117) W move(11,5)
# game(2) step(117) W move(14,4)
# game(0) step(118) B move(7,8)
# game(1) step(118) B move(8,4)
# game(2) step(118) B move(13,6)
# game(0) step(119) W move(8,8)
# game(1) step(119) W move(16,1)
# game(2) step(119) W move(12,7)
# game(0) step(120) B move(7,9)
# game(1) step(120) B move(17,1)
# game(2) step(120) B move(13,8)
# game(0) step(121) W move(7,10)
# game(1) step(121) W move(9,3)
# game(2) step(121) W move(10,9)
# game(0) step(122) B move(8,10)
# game(1) step(122) B move(9,6)
# game(2) step(122) B move(10,8)
# game(0) step(123) W move(7,11)
# game(1) step(123) W move(18,1)
# game(2) step(123) W move(10,12)
# game(0) step(124) B move(8,12)
# game(1) step(124) B move(17,0)
# game(2) step(124) B move(12,8)
# game(0) step(125) W move(7,12)
# game(1) step(125) W move(18,7)
# game(2) step(125) W move(9,7)
# game(0) step(126) B move(7,13)
# game(1) step(126) B move(3,4)
# game(2) step(126) B move(9,8)
# game(0) step(127) W move(2,14)
# game(1) step(127) W move(2,5)
# game(2) step(127) W move(8,8)
# game(0) step(128) B move(3,10)
# game(1) step(128) B move(2,3)
# game(2) step(128) B move(9,9)
# game(0) step(129) W move(7,7)
# game(1) step(129) W move(3,3)
# game(2) step(129) W move(11,11)
# game(0) step(130) B move(6,8)
# game(1) step(130) B move(2,2)
# game(2) step(130) B move(8,7)
# game(0) step(131) W move(5,8)
# game(1) step(131) W move(2,1)
# game(2) step(131) W move(7,8)
# game(0) step(132) B move(6,7)
# game(1) step(132) B move(3,1)
# game(2) step(132) B move(7,7)
# game(0) step(133) W move(5,10)
# game(1) step(133) W move(4,1)
# game(2) step(133) W move(6,8)
# game(0) step(134) B move(8,7)
# game(1) step(134) B move(1,1)
# game(2) step(134) B move(9,6)
# game(0) step(135) W move(9,7)
# game(1) step(135) W move(3,0)
# game(2) step(135) W move(10,6)
# game(0) step(136) B move(7,6)
# game(1) step(136) B move(11,8)
# game(2) step(136) B move(10,7)
# game(0) step(137) W move(5,7)
# game(1) step(137) W move(12,8)
# game(2) step(137) W move(7,5)
# game(0) step(138) B move(9,6)
# game(1) step(138) B move(11,9)
# game(2) step(138) B move(8,12)
# game(0) step(139) W move(10,7)
# game(1) step(139) W move(11,7)
# game(2) step(139) W move(9,10)
# game(0) step(140) B move(8,6)
# game(1) step(140) B move(12,10)
# game(2) step(140) B move(16,1)
# game(0) step(141) W move(6,6)
# game(1) step(141) W move(13,10)
# game(2) step(141) W move(16,3)
# game(0) step(142) B move(7,7)
# game(1) step(142) B move(12,11)
# game(2) step(142) B move(11,7)
# game(0) step(143) W move(5,6)
# game(1) step(143) W move(9,4)
# game(2) step(143) W move(7,6)
# game(0) step(144) B move(7,5)
# game(1) step(144) B move(7,6)
# game(2) step(144) B move(15,1)
# game(0) step(145) W move(7,3)
# game(1) step(145) W move(6,16)
# game(2) step(145) W move(6,7)
# game(0) step(146) B move(10,6)
# game(1) step(146) B move(6,17)
# game(2) step(146) B move(17,2)
# game(0) step(147) W move(9,10)
# game(1) step(147) W move(7,16)
# game(2) step(147) W move(17,3)
# game(0) step(148) B move(9,11)
# game(1) step(148) B move(8,15)
# game(2) step(148) B move(18,1)
# game(0) step(149) W move(10,11)
# game(1) step(149) W move(7,17)
# game(2) step(149) W move(17,0)
# game(0) step(150) B move(8,13)
# game(1) step(150) B move(7,18)
# game(2) step(150) B move(17,1)
# game(0) step(151) W move(14,17)
# game(1) step(151) W move(8,16)
# game(2) step(151) W move(7,15)
# game(0) step(152) B move(17,14)
# game(1) step(152) B move(10,14)
# game(2) step(152) B move(7,16)
# game(0) step(153) W move(8,3)
# game(1) step(153) W move(5,18)
# game(2) step(153) W move(8,14)
# game(0) step(154) B move(9,2)
# game(1) step(154) B move(13,1)
# game(2) step(154) B move(9,14)
# game(0) step(155) W move(6,3)
# game(1) step(155) W move(13,3)
# game(2) step(155) W move(9,13)
# game(0) step(156) B move(5,2)
# game(1) step(156) B move(3,5)
# game(2) step(156) B move(9,15)
# game(0) step(157) W move(10,4)
# game(1) step(157) W move(2,6)
# game(2) step(157) W move(2,16)
# game(0) step(158) B move(12,0)
# game(1) step(158) B move(4,2)
# game(2) step(158) B move(3,17)
# game(0) step(159) W move(11,0)
# game(1) step(159) W move(4,3)
# game(2) step(159) W move(3,15)
# game(0) step(160) B move(13,0)
# game(1) step(160) B move(5,2)
# game(2) step(160) B move(4,15)
# game(0) step(161) W move(10,1)
# game(1) step(161) W move(5,3)
# game(2) step(161) W move(8,13)
# game(0) step(162) B move(17,12)
# game(1) step(162) B move(6,2)
# game(2) step(162) B move(4,14)
# game(0) step(163) W move(10,2)
# game(1) step(163) W move(6,3)
# game(2) step(163) W move(3,12)
# game(0) step(164) B move(16,11)
# game(1) step(164) B move(7,3)
# game(2) step(164) B move(3,13)
# game(0) step(165) W move(17,11)
# game(1) step(165) W move(7,2)
# game(2) step(165) W move(2,13)
# game(0) step(166) B move(11,13)
# game(1) step(166) B move(8,2)
# game(2) step(166) B move(6,14)
# game(0) step(167) W move(10,12)
# game(1) step(167) W move(7,1)
# game(2) step(167) W move(2,17)
# game(0) step(168) B move(9,9)
# game(1) step(168) B move(8,1)
# game(2) step(168) B move(4,12)
# game(0) step(169) W move(3,9)
# game(1) step(169) W move(8,3)
# game(2) step(169) W move(3,11)
# game(0) step(170) B move(10,10)
# game(1) step(170) B move(7,4)
# game(2) step(170) B move(4,11)
# game(0) step(171) W move(18,5)
# game(1) step(171) W move(9,1)
# game(2) step(171) W move(4,10)
# game(0) step(172) B move(9,10)
# game(1) step(172) B move(6,1)
# game(2) step(172) B move(5,10)
# game(0) step(173) W move(2,5)
# game(1) step(173) W move(9,2)
# game(2) step(173) W move(4,9)
# game(0) step(174) B move(3,5)
# game(1) step(174) B move(13,14)
# game(2) step(174) B move(7,10)
# game(0) step(175) W move(2,6)
# game(1) step(175) W move(8,0)
# game(2) step(175) W move(8,9)
# game(0) step(176) B move(2,7)
# game(1) step(176) B move(13,17)
# game(2) step(176) B move(1,7)
# game(0) step(177) W move(1,5)
# game(1) step(177) W move(12,17)
# game(2) step(177) W move(17,14)
# game(0) step(178) B move(1,7)
# game(1) step(178) B move(14,17)
# game(2) step(178) B move(17,13)
# game(0) step(179) W move(2,3)
# game(1) step(179) W move(6,12)
# game(2) step(179) W move(18,14)
# game(0) step(180) B move(2,2)
# game(1) step(180) B move(7,12)
# game(2) step(180) B move(1,4)
# game(0) step(181) W move(1,2)
# game(1) step(181) W move(7,15)
# game(2) step(181) W move(0,6)
# game(0) step(182) B move(1,3)
# game(1) step(182) B move(7,14)
# game(2) step(182) B move(0,3)
# game(0) step(183) W move(2,4)
# game(1) step(183) W move(8,14)
# game(2) step(183) W move(0,4)
# game(0) step(184) B move(1,1)
# game(1) step(184) B move(7,13)
# game(2) step(184) B move(0,5)
# game(0) step(185) W move(3,2)
# game(1) step(185) W move(10,13)
# game(2) step(185) W move(1,8)
# game(0) step(186) B move(0,2)
# game(1) step(186) B move(9,13)
# game(2) step(186) B move(1,6)
# game(0) step(187) W move(3,4)
# game(1) step(187) W move(9,16)
# game(2) step(187) W move(1,2)
# game(0) step(188) B move(4,3)
# game(1) step(188) B move(11,13)
# game(2) step(188) B move(7,12)
# game(0) step(189) W move(4,4)
# game(1) step(189) W move(14,0)
# game(2) step(189) W move(13,1)
# game(0) step(190) B move(5,3)
# game(1) step(190) B move(13,0)
# game(2) step(190) B move(12,1)
# game(0) step(191) W move(5,4)
# game(1) step(191) W move(15,0)
# game(2) step(191) W move(7,14)
# game(0) step(192) B move(11,9)
# game(1) step(192) B move(12,14)
# game(2) step(192) B move(2,4)
# game(0) step(193) W move(18,11)
# game(1) step(193) W move(12,15)
# game(2) step(193) W move(3,4)
# game(0) step(194) B move(16,13)
# game(1) step(194) B move(11,17)
# game(2) step(194) B move(9,12)
# game(0) step(195) W move(3,13)
# game(1) step(195) W move(11,18)
# game(2) step(195) W move(10,13)
# game(0) step(196) B move(2,13)
# game(1) step(196) B move(5,5)
# game(2) step(196) B move(17,15)
# game(0) step(197) W move(4,14)
# game(1) step(197) W move(6,5)
# game(2) step(197) W move(6,13)
# game(0) step(198) B move(4,13)
# game(1) step(198) B move(6,4)
# game(2) step(198) B move(0,7)
# game(0) step(199) W move(5,13)
# game(1) step(199) W move(5,4)
# game(2) step(199) W move(6,12)
# game(0) step(200) B move(3,14)
# game(1) step(200) B move(7,5)
# game(2) step(200) B move(6,11)
# game(0) step(201) W move(5,14)
# game(1) step(201) W move(4,5)
# game(2) step(201) W move(3,18)
# game(0) step(202) B move(1,14)
# game(1) step(202) B move(14,10)
# game(2) step(202) B move(4,18)
# game(0) step(203) W move(2,9)
# game(1) step(203) W move(13,9)
# game(2) step(203) W move(2,18)
# game(0) step(204) B move(5,12)
# game(1) step(204) B move(5,0)
# game(2) step(204) B move(3,14)
# game(0) step(205) W move(1,10)
# game(1) step(205) W move(7,0)
# game(2) step(205) W move(6,15)
# game(0) step(206) B move(9,1)
# game(1) step(206) B move(2,11)
# game(2) step(206) B move(5,13)
# game(0) step(207) W move(9,0)
# game(1) step(207) W move(1,12)
# game(2) step(207) W move(5,14)
# game(0) step(208) B move(8,0)
# game(1) step(208) B move(2,8)
# game(2) step(208) B move(5,16)
# game(0) step(209) W move(1,12)
# game(1) step(209) W move(1,7)
# game(2) step(209) W move(5,12)
# game(0) step(210) B move(10,0)
# game(1) step(210) B move(3,10)
# game(2) step(210) B move(4,13)
# game(0) step(211) W move(15,18)
# game(1) step(211) W move(1,8)
# game(2) step(211) W move(5,11)
# game(0) step(212) B move(9,8)
# game(1) step(212) B move(0,11)
# game(2) step(212) B move(2,12)
# game(0) step(213) W move(9,0)
# game(1) step(213) W move(2,9)
# game(2) step(213) W move(2,15)
# game(0) step(214) B move(6,5)
# game(1) step(214) B move(3,9)
# game(2) step(214) B move(5,15)
# game(0) step(215) W move(6,4)
# game(1) step(215) W move(3,8)
# game(2) step(215) W move(5,9)
# game(0) step(216) B move(7,2)
# game(1) step(216) B move(1,9)
# game(2) step(216) B move(6,14)
# game(0) step(217) W move(9,3)
# game(1) step(217) W move(2,7)
# game(2) step(217) W move(6,10)
# game(0) step(218) B move(12,12)
# game(1) step(218) B move(5,7)
# game(2) step(218) B move(7,13)
# game(0) step(219) W move(11,12)
# game(1) step(219) W move(10,7)
# game(2) step(219) W move(5,14)
# game(0) step(220) B move(10,0)
# game(1) step(220) B move(4,18)
# game(2) step(220) B move(7,11)
# game(0) step(221) W move(16,1)
# game(1) step(221) W move(6,7)
# game(2) step(221) W move(6,14)
# game(0) step(222) B move(17,0)
# game(1) step(222) B move(6,18)
# game(2) step(222) B move(10,11)
# game(0) step(223) W move(9,0)
# game(1) step(223) W move(8,18)
# game(2) step(223) W move(10,14)
# game(0) step(224) B move(16,0)
# game(1) step(224) B move(17,10)
# game(2) step(224) B move(9,11)
# game(0) step(225) W move(12,4)
# game(1) step(225) W move(18,4)
# game(2) step(225) W move(10,10)
# game(0) step(226) B move(0,5)
# game(1) step(226) B move(2,17)
# game(2) step(226) B move(11,13)
# game(0) step(227) W move(0,4)
# game(1) step(227) W move(3,17)
# game(2) step(227) W move(11,12)
# game(0) step(228) B move(0,6)
# game(1) step(228) B move(3,18)
# game(2) step(228) B move(5,1)
# game(0) step(229) W move(1,8)
# game(1) step(229) W move(1,17)
# game(2) step(229) W move(7,1)
# game(0) step(230) B move(10,0)
# game(1) step(230) B move(1,16)
# game(2) step(230) B move(12,12)
# game(0) step(231) W move(11,1)
# game(1) step(231) W move(2,16)
# game(2) step(231) W move(3,0)
# game(0) step(232) B move(15,1)
# game(1) step(232) B move(2,15)
# game(2) step(232) B move(16,8)
# game(0) step(233) W move(9,0)
# game(1) step(233) W move(2,18)
# game(2) step(233) W move(15,12)
# game(0) step(234) B move(2,10)
# game(1) step(234) B move(1,14)
# game(2) step(234) B move(15,13)
# game(0) step(235) W move(4,11)
# game(1) step(235) W move(5,18)
# game(2) step(235) W move(18,13)
# game(0) step(236) B move(10,0)
# game(1) step(236) B move(18,12)
# game(2) step(236) B move(7,9)
# game(0) step(237) W move(4,12)
# game(1) step(237) W move(10,8)
# game(2) step(237) W move(13,11)
# game(0) step(238) B move(4,10)
# game(1) step(238) B move(18,0)
# game(2) step(238) B move(13,12)
# game(0) step(239) W move(2,11)
# game(1) step(239) W move(10,9)
# game(2) step(239) W move(17,12)
# game(0) step(240) B move(3,11)
# game(1) step(240) B move(11,10)
# game(2) step(240) B move(14,13)
# game(0) step(241) W move(5,11)
# game(1) step(241) W move(9,10)
# game(2) step(241) W move(9,0)
# game(0) step(242) B move(3,13)
# game(1) step(242) B move(8,10)
# game(2) step(242) B move(18,12)
# game(0) step(243) W move(2,12)
# game(1) step(243) W move(8,11)
# game(2) step(243) W move(18,15)
# game(0) step(244) B move(6,12)
# game(1) step(244) B move(8,12)
# game(2) step(244) B move(1,10)
# game(0) step(245) W move(6,13)
# game(1) step(245) W move(9,9)
# game(2) step(245) W move(4,17)
# game(0) step(246) B move(6,10)
# game(1) step(246) B move(7,11)
# game(2) step(246) B move(4,16)
# game(0) step(247) W move(1,13)
# game(1) step(247) W move(9,11)
# game(2) step(247) W move(5,18)
# game(0) step(248) B move(5,9)
# game(1) step(248) B move(8,9)
# game(2) step(248) B move(6,18)
# game(0) step(249) W move(2,14)
# game(1) step(249) W move(9,7)
# game(2) step(249) W move(8,16)
# game(0) step(250) B move(6,11)
# game(1) step(250) B move(8,8)
# game(2) step(250) B move(8,17)
# game(0) step(251) W move(17,16)
# game(1) step(251) W move(18,10)
# game(2) step(251) W move(6,17)
# game(0) step(252) B move(17,17)
# game(1) step(252) B move(18,11)
# game(2) step(252) B move(7,18)
# game(0) step(253) W move(2,1)
# game(1) step(253) W move(18,9)
# game(2) step(253) W move(5,17)
# game(0) step(254) B move(1,2)
# game(1) step(254) B move(0,17)
# game(2) step(254) B move(7,17)
# game(0) step(255) W move(12,17)
# game(1) step(255) W move(1,18)
# game(2) step(255) W move(17,10)
# game(0) step(256) B move(12,16)
# game(1) step(256) B move(1,15)
# game(2) step(256) B move(16,10)
# game(0) step(257) W move(13,16)
# game(1) step(257) W move(2,14)
# game(2) step(257) W move(15,7)
# game(0) step(258) B move(11,17)
# game(1) step(258) B move(18,2)
# game(2) step(258) B move(18,10)
# game(0) step(259) W move(1,4)
# game(1) step(259) W move(13,18)
# game(2) step(259) W move(4,18)
# game(0) step(260) B move(12,18)
# game(1) step(260) B move(1,0)
# game(2) step(260) B move(1,13)
# game(0) step(261) W move(9,0)
# game(1) step(261) W move(14,18)
# game(2) step(261) W move(1,14)
# game(0) step(262) B move(2,8)
# game(1) step(262) B move(15,17)
# game(2) step(262) B move(1,12)
# game(0) step(263) W move(4,5)
# game(1) step(263) W move(15,18)
# game(2) step(263) W move(8,6)
# game(0) step(264) B move(3,7)
# game(1) step(264) B move(16,17)
# game(2) step(264) B move(9,7)
# game(0) step(265) W move(0,8)
# game(1) step(265) W move(16,18)
# game(2) step(265) W move(2,11)
# game(0) step(266) B move(4,8)
# game(1) step(266) B move(17,17)
# game(2) step(266) B move(1,11)
# game(0) step(267) W move(6,9)
# game(1) step(267) W move(6,5)
# game(2) step(267) W move(17,8)
# game(0) step(268) B move(12,15)
# game(1) step(268) B move(1,4)
# game(2) step(268) B move(17,9)
# game(0) step(269) W move(12,11)
# game(1) step(269) W move(10,3)
# game(2) step(269) W move(18,8)
# game(0) step(270) B move(5,9)
# game(1) step(270) B move(5,5)
# game(2) step(270) B move(5,0)
# game(0) step(271) W move(13,12)
# game(1) step(271) W move(4,9)
# game(2) step(271) W move(18,9)
# game(0) step(272) B move(12,13)
# game(1) step(272) B move(1,5)
# game(2) step(272) B move(10,0)
# game(0) step(273) W move(6,9)
# game(1) step(273) W move(5,1)
# game(2) step(273) W move(10,2)
# game(0) step(274) B move(10,0)
# game(1) step(274) B move(2,10)
# game(2) step(274) B move(8,0)
# game(0) step(275) W move(15,13)
# game(1) step(275) W move(0,12)
# game(2) step(275) W move(13,0)
# game(0) step(276) B move(5,9)
# game(1) step(276) B move(0,9)
# game(2) step(276) B move(11,2)
# game(0) step(277) W move(11,6)
# game(1) step(277) W move(16,10)
# game(2) step(277) W move(9,16)
# game(0) step(278) B move(12,6)
# game(1) step(278) B move(2,8)
# game(2) step(278) B move(9,17)
# game(0) step(279) W move(11,7)
# game(1) step(279) W move(17,11)
# game(2) step(279) W move(3,7)
# game(0) step(280) B move(11,5)
# game(1) step(280) B move(17,13)
# game(2) step(280) B move(10,16)
# game(0) step(281) W move(10,5)
# game(1) step(281) W move(2,9)
# game(2) step(281) W move(10,1)
# game(0) step(282) B move(10,8)
# game(1) step(282) B move(0,8)
# game(2) step(282) B move(0,14)
# game(0) step(283) W move(9,5)
# game(1) step(283) W move(15,10)
# game(2) step(283) W move(0,15)
# game(0) step(284) B move(5,5)
# game(1) step(284) B move(17,12)
# game(2) step(284) B move(0,13)
# game(0) step(285) W move(4,6)
# game(1) step(285) W move(14,11)
# game(2) step(285) W move(6,9)
# game(0) step(286) B move(11,4)
# game(1) step(286) B move(14,12)
# game(2) step(286) B move(9,0)
# game(0) step(287) W move(11,3)
# game(1) step(287) W move(14,10)
# game(2) step(287) W move(12,0)
# game(0) step(288) B move(6,18)
# game(1) step(288) B move(17,10)
# game(2) step(288) B move(11,0)
# game(0) step(289) W move(5,18)
# game(1) step(289) W move(0,7)
# game(2) step(289) W move(15,0)
# game(0) step(290) B move(7,18)
# game(1) step(290) B move(9,12)
# game(2) step(290) B move(18,0)
# game(0) step(291) W move(13,7)
# game(1) step(291) W move(17,11)
# game(2) step(291) W move(14,0)
# game(0) step(292) B move(18,16)
# game(1) step(292) B move(17,18)
# game(2) step(292) B move(16,0)
# game(0) step(293) W move(9,0)
# game(1) step(293) W move(15,12)
# game(2) step(293) W move(18,3)
# game(0) step(294) B move(1,18)
# game(1) step(294) B move(16,12)
# game(2) step(294) B move(17,7)
# game(0) step(295) W move(2,18)
# game(1) step(295) W move(13,12)
# game(2) step(295) W move(17,6)
# game(0) step(296) B move(8,4)
# game(1) step(296) B move(15,13)
# game(2) step(296) B move(18,7)
# game(0) step(297) W move(14,18)
# game(1) step(297) W move(12,18)
# game(2) step(297) W move(18,6)
# game(0) step(298) B move(1,9)
# game(1) step(298) B move(0,3)
# game(2) step(298) B move(18,2)
# game(0) step(299) W move(0,9)
# game(1) step(299) W move(3,6)
# game(2) step(299) W move(0,8)
# game(0) step(300) B move(10,0)
# game(1) step(300) B move(1,11)
# game(2) step(300) B move(0,16)
# game(0) step(301) W move(10,13)
# game(1) step(301) W move(2,8)
# game(2) step(301) W move(1,15)
# game(0) step(302) B move(10,14)
# game(1) step(302) B move(17,10)
# game(2) step(302) B move(1,16)
# game(0) step(303) W move(1,0)
# game(1) step(303) W move(6,5)
# game(2) step(303) W move(0,17)
# game(0) step(304) B move(3,1)
# game(1) step(304) B move(2,0)
# game(2) step(304) B move(17,4)
# game(0) step(305) W move(3,8)
# game(1) step(305) W move(3,1)
# game(2) step(305) W move(14,2)
# game(0) step(306) B move(13,13)
# game(1) step(306) B move(5,5)
# game(2) step(306) B move(1,9)
# game(0) step(307) W move(9,0)
# game(1) step(307) W move(5,7)
# game(2) step(307) W move(0,9)
# game(0) step(308) B move(9,13)
# game(1) step(308) B move(8,5)
# game(2) step(308) B move(18,4)
# game(0) step(309) W move(11,11)
# game(1) step(309) W move(17,11)
# game(2) step(309) W move(16,4)
# game(0) step(310) B move(10,0)
# game(1) step(310) B move(3,14)
# game(2) step(310) B move(17,5)
# game(0) step(311) W move(4,7)
# game(1) step(311) W move(3,13)
# game(2) step(311) W move(18,5)
# game(0) step(312) B move(0,13)
# game(1) step(312) B move(1,13)
# game(2) step(312) B move(2,10)
# game(0) step(313) W move(9,0)
# game(1) step(313) W move(4,14)
# game(2) step(313) W move(0,10)
# game(0) step(314) B move(11,8)
# game(1) step(314) B move(17,10)
# game(2) step(314) B move(3,10)
# game(0) step(315) W move(13,18)
# game(1) step(315) W move(7,7)
# game(2) step(315) W move(0,11)
# game(0) step(316) B move(10,0)
# game(1) step(316) B move(17,11)
# game(2) step(316) B move(9,3)
# game(0) step(317) W move(12,17)
# game(1) step(317) W move(4,12)
# game(2) step(317) W move(12,6)
# game(0) step(318) B move(11,18)
# game(1) step(318) B move(0,13)
# game(2) step(318) B move(12,7)
# game(0) step(319) W move(9,0)
# game(1) step(319) W move(0,16)
# game(2) step(319) W move(0,2)
# game(0) step(320) B move(7,0)
# game(1) step(320) B move(0,15)
# game(2) step(320) B move(8,4)
# game(0) step(321) W move(13,17)
# game(1) step(321) W move(4,11)
# game(2) step(321) W move(8,5)
# game(0) step(322) B move(10,0)
# game(1) step(322) B move(11,0)
# game(2) step(322) B move(0,12)
# game(0) step(323) W move(16,18)
# game(1) step(323) W move(13,2)
# game(2) step(323) W move(2,7)
# game(0) step(324) B move(17,18)
# game(1) step(324) B move(16,0)
# game(2) step(324) B move(2,3)
# game(0) step(325) W move(9,0)
# game(1) step(325) W move(12,0)
# game(2) step(325) W move(2,2)
# game(0) step(326) B move(0,1)
# game(1) step(326) B move(10,0)
# game(2) step(326) B move(6,0)
# game(0) step(327) W move(0,3)
# game(1) step(327) W move(0,6)
# game(2) step(327) W move(8,3)
# game(0) step(328) B move(2,0)
# game(1) step(328) B move(0,5)
# game(2) step(328) B move(0,1)
# game(0) step(329) W move(7,4)
# game(1) step(329) W move(9,14)
# game(2) step(329) W move(1,1)
# game(0) step(330) B move(10,0)
# game(1) step(330) B move(8,13)
# game(2) step(330) B move(5,5)
# game(0) step(331) W move(18,2)
# game(1) step(331) W move(6,5)
# game(2) step(331) W move(4,5)
# game(0) step(332) B move(0,0)
# game(1) step(332) B move(8,6)
# game(2) step(332) B move(5,4)
# game(0) step(333) W move(9,0)
# game(1) step(333) W move(0,18)
# game(2) step(333) W move(0,4)
# game(0) step(334) B move(18,0)
# game(1) step(334) B move(5,5)
# game(2) step(334) B move(10,15)
# game(0) step(335) W move(10,0)
# game(1) step(335) W move(4,4)
# game(2) step(335) W move(0,6)
# game(0) step(336) B move(15,12)
# game(1) step(336) B move(12,1)
# game(2) step(336) B move(7,4)
# game(0) step(337) W move(14,12)
# game(1) step(337) W move(13,1)
# game(2) step(337) W move(6,4)
# game(0) step(338) B move(18,13)
# game(1) step(338) B move(13,0)
# game(2) step(338) B move(1,0)
# game(0) step(339) W move(0,12)
# game(1) step(339) W move(1,2)
# game(2) step(339) W move(0,0)
# game(0) step(340) B move(3,13)
# game(1) step(340) B move(1,3)
# game(2) step(340) B move(1,17)
# game(0) step(341) W move(18,14)
# game(1) step(341) W move(0,16)
# game(2) step(341) W move(1,18)
# game(0) step(342) B move(18,15)
# game(1) step(342) B move(18,8)
# game(2) step(342) B move(0,1)
# game(0) step(343) W move(18,17)
# game(1) step(343) W move(17,8)
# game(2) step(343) W move(8,11)
# game(0) step(344) B move(18,18)
# game(1) step(344) B move(0,17)
# game(2) step(344) B move(8,16)
# game(0) step(345) W move(6,9)
# game(1) step(345) W move(0,1)
# game(2) step(345) W move(5,7)
# game(0) step(346) B move(12,3)
# game(1) step(346) B move(0,2)
# game(2) step(346) B move(14,1)
# game(0) step(347) W move(15,0)
# game(1) step(347) W move(0,16)
# game(2) step(347) W move(17,0)
# game(0) step(348) B move(5,9)
# game(1) step(348) B move(6,5)
# game(2) step(348) B move(12,9)
# game(0) step(349) W move(16,1)
# game(1) step(349) W move(0,14)
# game(2) step(349) W move(14,11)
# game(0) step(350) B move(0,11)
# game(1) step(350) B move(17,7)
# game(2) step(350) B move(17,8)
# game(0) step(351) W move(6,9)
# game(1) step(351) W move(16,7)
# game(2) step(351) W move(15,18)
# game(0) step(352) B move(8,1)
# game(1) step(352) B move(10,1)
# game(2) step(352) B move(13,18)
# game(0) step(353) W move(5,9)
# game(1) step(353) W move(12,2)
# game(2) step(353) W move(2,9)
# game(0) step(354) B move(4,18)
# game(1) step(354) B move(1,6)
# game(2) step(354) B move(11,3)
# game(0) step(355) W move(5,17)
# game(1) step(355) W move(14,13)
# game(2) step(355) W move(18,9)
# game(0) step(356) B move(3,18)
# game(1) step(356) B move(13,13)
# game(2) step(356) B move(18,8)
# game(0) step(357) W move(3,17)
# game(1) step(357) W move(4,10)
# game(2) step(357) W move(4,0)
# game(0) step(358) B move(2,17)
# game(1) step(358) B move(12,0)
# game(2) step(358) B move(11,9)
# game(0) step(359) W move(0,14)
# game(1) step(359) W move(9,0)
# game(2) step(359) W move(6,6)
# game(0) step(360) B move(2,18)
# game(1) step(360) B move(8,2)
# game(2) step(360) B move(8,4)
# game(0) step(361) W move(0,15)
# game(1) step(361) W move(0,10)
# game(2) step(361) W move(7,4)
# game(0) step(362) B move(4,2)
# game(1) step(362) B move(1,15)
# game(2) step(362) B move(0,7)
# game(0) step(363) W move(4,17)
# game(1) step(363) W move(1,14)
# game(2) step(363) W move(15,4)
# game(0) step(364) B move(8,18)
# game(1) step(364) B move(0,0)
# game(2) step(364) B move(3,11)
# game(0) step(365) W move(0,7)
# game(1) step(365) W move(10,2)
# game(2) step(365) W move(15,10)
# game(0) step(366) B move(5,15)
# game(1) step(366) B move(10,18)
# game(2) step(366) B move(17,12)
# game(0) step(367) W move(0,18)
# game(1) step(367) W move(9,18)
# game(2) step(367) W move(0,0)
# game(0) step(368) B move(18,10)
# game(1) step(368) B move(11,11)
# game(2) step(368) B move(1,16)
# game(0) step(369) W move(18,9)
# game(1) step(369) W move(12,13)
# game(2) step(369) W move(0,16)
# game(0) step(370) B move(17,0)
# game(1) step(370) B move(12,12)
# game(2) step(370) B move(0,1)
# game(0) step(371) W move(17,10)
# game(1) step(371) W move(6,0)
# game(2) step(371) W move(2,0)
# game(0) step(372) B move(18,0)
# game(1) step(372) B move(13,12)
# game(2) step(372) B move(9,11)
# game(0) step(373) W move(17,1)
# game(1) step(373) W move(4,0)
# game(2) step(373) W move(1,6)
# game(0) step(374) B move(9,14)
# game(1) step(374) B move(8,14)
# game(2) step(374) B move(5,0)
# game(0) step(375) W move(6,0)
# game(1) step(375) W move(10,10)
# game(2) step(375) W move(5,1)
# game(0) step(376) B move(6,1)
# game(1) step(376) B move(1,16)
# game(2) step(376) B move(14,14)
# game(0) step(377) W move(16,0)
# game(1) step(377) W move(0,15)
# game(2) step(377) W move(17,18)
# game(0) step(378) B move(5,0)
# game(1) step(378) B move(3,4)
# game(2) step(378) B move(7,12)
# game(0) step(379) W move(4,13)
# game(1) step(379) W move(3,5)
# game(2) step(379) W move(7,11)
# game(0) step(380) B move(3,14)
# game(1) step(380) B move(6,2)
# game(2) step(380) B move(8,12)
# game(0) step(381) W move(0,16)
# game(1) step(381) W move(5,2)
# game(2) step(381) W move(9,12)
# game(0) step(382) B move(14,4)
# game(1) step(382) B move(13,0)
# game(2) step(382) B move(18,18)
# game(0) step(383) W move(15,4)
# game(1) step(383) W move(6,1)
# game(2) step(383) W move(18,17)
# game(0) step(384) B move(2,18)
# game(1) step(384) B move(12,0)
# game(2) step(384) B move(16,1)
# game(0) step(385) W move(2,17)
# game(1) step(385) W move(11,0)
# game(2) step(385) W move(17,1)
# game(0) step(386) B move(3,18)
# game(1) step(386) B move(7,10)
# game(2) step(386) B move(18,2)
# game(0) step(387) W move(1,18)
# game(1) step(387) W move(12,1)
# game(2) step(387) W move(17,2)
# game(0) step(388) B move(15,8)
# game(1) step(388) B move(13,0)
# game(2) step(388) B move(18,1)
# game(0) step(389) W move(15,10)
# game(1) step(389) W move(12,0)
# game(2) step(389) W move(18,0)
# game(0) step(390) B move(18,0)
# game(1) step(390) B move(10,0)
# game(2) step(390) B move(15,1)
# game(0) step(391) W move(10,3)
# game(1) step(391) W move(10,1)
# game(2) step(391) W move(16,0)
# game(0) step(392) B move(18,7)
# game(1) step(392) B move(0,9)
# game(2) step(392) B move(14,1)
# game(0) step(393) W move(18,6)
# game(1) step(393) W move(1,9)
# game(2) step(393) W move(15,2)
# game(0) step(394) B move(16,8)
# game(1) step(394) B move(1,10)
# game(2) step(394) B move(16,5)
# game(0) step(395) W move(17,8)
# game(1) step(395) W move(0,8)
# game(2) step(395) W move(17,5)
# game(0) step(396) B move(14,14)
# game(1) step(396) B move(2,10)
# game(2) step(396) B move(10,3)
# game(0) step(397) W move(14,15)
# game(1) step(397) W move(3,10)
# game(2) step(397) W move(0,0)
# game(0) step(398) B move(11,15)
# game(1) step(398) B move(1,11)
# game(2) step(398) B move(10,1)
# game(0) step(399) W move(15,7)
# game(1) step(399) W move(2,11)
# game(2) step(399) W move(10,11)
# game(0) step(400) B move(0,10)
# game(1) step(400) B move(3,11)
# game(2) step(400) B move(12,6)
# game(0) step(401) W move(9,4)
# game(1) step(401) W move(8,1)
# game(2) step(401) W move(3,1)
# game(0) step(402) B move(7,10)
# game(1) step(402) B move(6,18)
# game(2) step(402) B move(18,4)
# game(0) step(403) W move(7,11)
# game(1) step(403) W move(7,18)
# game(2) step(403) W move(17,4)
# game(0) step(404) B move(7,12)
# game(1) step(404) B move(4,18)
# game(2) step(404) B move(15,1)
# game(0) step(405) W move(4,1)
# game(1) step(405) W move(3,18)
# game(2) step(405) W move(14,1)
# game(0) step(406) B move(5,1)
# game(1) step(406) B move(5,17)
# game(2) step(406) B move(12,15)
# game(0) step(407) W move(14,0)
# game(1) step(407) W move(6,17)
# game(2) step(407) W move(6,5)
# game(0) step(408) B move(4,0)
# game(1) step(408) B move(18,17)
# game(2) step(408) B move(5,5)
# game(0) step(409) W move(4,18)
# game(1) step(409) W move(17,14)
# game(2) step(409) W move(5,6)
# game(0) step(410) B move(13,0)
# game(1) step(410) B move(16,14)
# game(2) step(410) B move(4,8)
# game(0) step(411) W move(13,1)
# game(1) step(411) W move(17,15)
# game(2) step(411) W move(3,8)
# game(0) step(412) B move(11,6)
# game(1) step(412) B move(17,16)
# game(2) step(412) B move(5,2)
# game(0) step(413) W move(12,0)
# game(1) step(413) W move(18,16)
# game(2) step(413) W move(6,0)
# game(0) step(414) B move(14,1)
# game(1) step(414) B move(18,15)
# game(2) step(414) B move(12,18)
# game(0) step(415) W move(3,12)
# game(1) step(415) W move(18,14)
# game(2) step(415) W move(11,17)
# game(0) step(416) B move(3,7)
# game(1) step(416) B move(18,13)
# game(2) step(416) B move(11,16)
# game(0) step(417) W move(17,0)
# game(1) step(417) W move(2,15)
# game(2) step(417) W move(11,18)
# game(0) step(418) B move(3,6)
# game(1) step(418) B move(15,16)
# game(2) step(418) B move(10,17)
# game(0) step(419) W move(3,5)
# game(1) step(419) W move(3,12)
# game(2) step(419) W move(7,13)
# game(0) step(420) B move(2,7)
# game(1) step(420) B move(1,16)
# game(2) step(420) B move(10,18)
# game(0) step(421) W move(1,7)
# game(1) step(421) W move(17,15)
# game(2) step(421) W move(9,18)
# game(0) step(422) B move(0,6)
# game(1) step(422) B move(17,14)
# game(2) step(422) B move(8,18)
# game(0) step(423) W move(13,10)
# game(1) step(423) W move(5,16)
# game(2) step(423) W move(1,17)
# game(0) step(424) B move(14,10)
# game(1) step(424) B move(0,13)
# game(2) step(424) B move(18,1)
# game(0) step(425) W move(13,3)
# game(1) step(425) W move(0,11)
# game(2) step(425) W move(18,2)
# game(0) step(426) B move(1,6)
# game(1) step(426) B move(1,10)
# game(2) step(426) B move(1,4)
# game(0) step(427) W move(2,8)
# game(1) step(427) W move(1,13)
# game(2) step(427) W move(2,4)
# game(0) step(428) B move(3,7)
# game(1) step(428) B move(1,11)
# game(2) step(428) B move(0,5)
# game(0) step(429) W move(13,0)
# game(1) step(429) W move(2,10)
# game(2) step(429) W move(1,5)
# game(0) step(430) B move(3,18)
# game(1) step(430) B move(1,10)
# game(2) step(430) B move(7,12)
# game(0) step(431) W move(2,18)
# game(1) step(431) W move(1,11)
# game(2) step(431) W move(8,12)
# game(0) step(432) B move(11,14)
# game(1) step(432) B PASS
# game(2) step(432) B move(6,2)
# game(0) step(433) W move(1,11)
# game(2) step(433) W move(4,2)
# game(0) step(434) B move(3,10)
# game(2) step(434) B move(7,10)
# game(0) step(435) W move(4,10)
# game(2) step(435) W move(4,3)
# game(0) step(436) B move(15,2)
# game(2) step(436) B move(11,18)
# game(0) step(437) W move(18,8)
# game(2) step(437) W move(5,4)
# game(0) step(438) B move(9,7)
# game(2) step(438) B move(5,2)
# game(0) step(439) W move(0,5)
# game(2) step(439) W move(6,2)
# game(0) step(440) B move(16,2)
# game(2) step(440) B move(2,6)
# game(0) step(441) W move(15,1)
# game(2) step(441) W move(1,7)
# game(0) step(442) B move(0,6)
# game(2) step(442) B PASS
# game(0) step(443) W move(14,4)
# game(0) step(444) B move(0,10)
# game(0) step(445) W move(1,6)
# game(0) step(446) B move(8,14)
# game(0) step(447) W move(10,7)
# game(0) step(448) B move(11,7)
# game(0) step(449) W move(0,11)
# game(0) step(450) B move(9,18)
# game(0) step(451) W move(10,17)
# game(0) step(452) B move(10,18)
# game(0) step(453) W move(3,11)
# game(0) step(454) B move(10,16)
# game(0) step(455) W move(4,15)
# game(0) step(456) B move(1,14)
# game(0) step(457) W move(9,17)
# game(0) step(458) B move(8,17)
# game(0) step(459) W move(14,2)
# game(0) step(460) B move(9,16)
# game(0) step(461) W move(10,17)
# game(0) step(462) B move(9,17)
# game(0) step(463) W move(16,4)
# game(0) step(464) B move(8,15)
# game(0) step(465) W move(9,15)
# game(0) step(466) B move(10,15)
# game(0) step(467) W move(2,7)
# game(0) step(468) B move(8,8)
# game(0) step(469) W move(15,5)
# game(0) step(470) B move(1,15)
# game(0) step(471) W move(2,15)
# game(0) step(472) B move(15,2)
# game(0) step(473) W move(16,2)
# game(0) step(474) B move(16,6)
# game(0) step(475) W move(2,10)
# game(0) step(476) B move(16,8)
# game(0) step(477) W move(2,13)
# game(0) step(478) B move(3,14)
# game(0) step(479) W move(14,9)
# game(0) step(480) B PASS

# %% [markdown]
# ### Record the game in SGF format

# %%
from sgfutil import GetWinner, WriteBackSGF
from datetime import datetime
import sgf

winner = [ GetWinner(game_state[i]) for i in range(GAMES_BATCHES) ] # B+, W+, T

#comment out for better performance
for i in range(GAMES_BATCHES):
    filename = os.path.join(
        os.path.expanduser('~'), 'python', 'tutorial_files','selfplay',
        '({}_{}_{})vs({}_{}_{})_{}_{}_{}'.format(PRIMARY_CONV_LEVEL, PRIMARY_FILTERS, PRIMARY_PRE_TRAINED_ITERS,
                                        SPARR_CONV_LEVEL, SPARR_FILTERS, SPARR_PRE_TRAINED_ITERS, i, winner[i],
                                        datetime.now().strftime("%Y-%m-%d")))
    print(filename)
    WriteBackSGF(winner, history[i], filename)
# Out:
# /home/wangd/python/tutorial_files/selfplay/(4_128_1)vs(13_192_1)_0_W+_2017-09-25
# /home/wangd/python/tutorial_files/selfplay/(4_128_1)vs(13_192_1)_1_W+_2017-09-25
# /home/wangd/python/tutorial_files/selfplay/(4_128_1)vs(13_192_1)_2_W+_2017-09-25

# %% [markdown]
# ## Learn from the winning games
#
# >We use a reward function $r(s)$ that is zero for all non-terminal time-steps $t < T$.
# The outcome $z_t = \pm r(s_T)$ is the terminal reward at the end of the game from the perspective of the
# current player at time-step $t$: $+1$ for winning and $-1$ for losing. Weights are then updated at each
# time-step $t$ by stochastic gradient ascent in the direction that maximizes expected outcome.

# %%
iter = 0
k = 0
for i in range(GAMES_BATCHES):
    print('Learning {} steps in {} of {} games.'.format(iter * 32, i, GAMES_BATCHES))
    for step in history[i]:
        if (step[0] == 'B' and winner[i] == 'B+') or (step[0] == 'W' and winner[i] == 'W+'):
            data[k] = step[3]
            label[k] = step[1]*19+step[2]
            k += 1
            if k == TRAIN_BATCHES:
                iter += 1
                k = 0
                workspace.SwitchWorkspace(PRIMARY_WORKSPACE)
                workspace.FeedBlob("data", data, device_option=device_opts)
                workspace.FeedBlob("label", label, device_option=device_opts)
                workspace.RunNet(primary_train_model.net)
# Out:
# Learning 0 steps in 0 of 3 games.
# Learning 96 steps in 1 of 3 games.
# Learning 224 steps in 2 of 3 games.

# %% [markdown]
# Now learning from negative examples.

# %%
iter = 0
k = 0
for i in range(GAMES_BATCHES):
    print('Learning negative examples {} steps in {} of {} games.'.format(iter * 32, i, GAMES_BATCHES))
    for step in history[i]:
        if (step[0] == 'B' and winner[i] == 'W+') or (step[0] == 'W' and winner[i] == 'B+'):
            data[k] = step[3]
            label[k] = step[1]*19+step[2]
            k += 1
            if k == TRAIN_BATCHES:
                iter += 1
                k = 0
                workspace.SwitchWorkspace(PRIMARY_WORKSPACE)
                workspace.FeedBlob("data", data, device_option=device_opts)
                workspace.FeedBlob("label", label, device_option=device_opts)
                workspace.RunNet(primary_train_neg_model.net)

print('Finished')
# Out:
# Learning negative examples 0 steps in 0 of 3 games.
# Learning negative examples 96 steps in 1 of 3 games.
# Learning negative examples 224 steps in 2 of 3 games.
# Finished

# %% [markdown]
# ### Save the RL model of primary player
# and also make a copy to opponent folder

# %%
if not os.path.exists(SAVE_FOLDER):
    os.makedirs(SAVE_FOLDER)
# construct the model to be exported
pe_meta = pe.PredictorExportMeta(
    predict_net=primary_deploy_model.net.Proto(),
    parameters=[str(b) for b in primary_deploy_model.params], 
    inputs=["data"],
    outputs=["predict"],
)
pe.save_to_db("minidb", os.path.join(SAVE_FOLDER, "policy_model.minidb"), pe_meta)
#pe.save_to_db("minidb", os.path.join(SPARR_FOLDER, "policy_model.minidb"), pe_meta)
print('Params saved to {}'.format(SAVE_FOLDER))
